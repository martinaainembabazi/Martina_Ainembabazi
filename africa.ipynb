# %%
#1.read the file
import pandas as pd
import numpy as py
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('AfricaCupofNationsMatches.csv')

# %%
#2.first 7 rows
df.head(7)
# Out:
#    Year      Date  Time    HomeTeam       AwayTeam  HomeTeamGoals  \
# 0  1957  10-Feb-57   NaN     Sudan           Egypt            1.0
# 1  1957  10-Feb-57   NaN  Ethiopia    South Africa            NaN
# 2  1957  16-Feb-57   NaN     Egypt        Ethiopia            4.0
# 3  1959  22-May-59   NaN      Egypt       Ethiopia            4.0
# 4  1959  25-May-59   NaN     Sudan        Ethiopia            1.0
# 5  1959  29-May-59   NaN      Egypt          Sudan            2.0
# 6  1962  14-Jan-62   NaN  Ethiopia         Tunisia            4.0
#
#    AwayTeamGoals             Stage  \
# 0            2.0        Semifinals
# 1            NaN        Semifinals
# 2            0.0             Final
# 3            0.0  Final Tournament
# 4            0.0  Final Tournament
# 5            1.0  Final Tournament
# 6            2.0        Semifinals
#
#                                 SpecialWinConditions                 Stadium  \
# ...

# %%
#select columns(use double square brackets)
df = df[['HomeTeam', 'AwayTeam', 'HomeTeamGoals', 'AwayTeamGoals']]
print(df.head)
# Out:
# <bound method NDFrame.head of         HomeTeam       AwayTeam  HomeTeamGoals  AwayTeamGoals
# 0         Sudan           Egypt            1.0            2.0
# 1      Ethiopia    South Africa            NaN            NaN
# 2         Egypt        Ethiopia            4.0            0.0
# 3          Egypt       Ethiopia            4.0            0.0
# 4         Sudan        Ethiopia            1.0            0.0
# ..           ...            ...            ...            ...
# 617  Madagascar         Tunisia            0.0            3.0
# 618     Senegal         Tunisia            1.0            0.0
# 619     Algeria         Nigeria            2.0            1.0
# 620     Tunisia         Nigeria            0.0            1.0
# 621     Senegal         Algeria            0.0            1.0
#
# [622 rows x 4 columns]>

# %%
#4.select rows where Egypt appears
egypt = df[(df['HomeTeam'] == 'Egypt') | (df['AwayTeam'] == 'Egypt')]
print(egypt.head())
# Out:
#      HomeTeam   AwayTeam  HomeTeamGoals  AwayTeamGoals
# 3       Egypt   Ethiopia            4.0            0.0
# 5       Egypt      Sudan            2.0            1.0
# 7       Egypt     Uganda            2.0            1.0
# 9   Ethiopia       Egypt            4.0            2.0
# 13      Egypt    Nigeria            6.0            3.0

# %%
#5.count rows and columns of dataframe
df.shape
# Out:
# (622, 4)

# %%
#select columns(use double square brackets)
df = pd.read_csv('AfricaCupofNationsMatches.csv')
df = df[['HomeTeam', 'AwayTeam', 'HomeTeamGoals', 'AwayTeamGoals','Attendance']]

# %%
#6.select rows where attendance is missing

missing_attendance=df[df['Attendance'].isna()]
print(missing_attendance.head())
# Out:
#      HomeTeam       AwayTeam  HomeTeamGoals  AwayTeamGoals  Attendance
# 1   Ethiopia    South Africa            NaN            NaN         NaN
# 8    Tunisia          Uganda            3.0            0.0         NaN
# 9   Ethiopia           Egypt            4.0            2.0         NaN
# 10     Ghana         Tunisia            1.0            1.0         NaN
# 11     Ghana        Ethiopia            2.0            0.0         NaN

# %%
#7.select where HomeTeamGoals is are between 3 and 6 inclusive
home_goals_3_to_6 = df[(df['HomeTeamGoals'] >= 3) & (df['HomeTeamGoals'] <= 6)]
print(home_goals_3_to_6.head())
# Out:
#     HomeTeam   AwayTeam  HomeTeamGoals  AwayTeamGoals  Attendance
# 2     Egypt    Ethiopia            4.0            0.0     30000.0
# 3      Egypt   Ethiopia            4.0            0.0     30000.0
# 6  Ethiopia     Tunisia            4.0            2.0     30000.0
# 8   Tunisia      Uganda            3.0            0.0         NaN
# 9  Ethiopia       Egypt            4.0            2.0         NaN

# %%
#8.program to change the "AwayTeamGoals" in the third row to 10
change_away=df.at[2, 'AwayTeamGoals'] = 10
print(df.head())
# Out:
#     HomeTeam       AwayTeam  HomeTeamGoals  AwayTeamGoals  Attendance
# 0     Sudan           Egypt            1.0            2.0     30000.0
# 1  Ethiopia    South Africa            NaN            NaN         NaN
# 2     Egypt        Ethiopia            4.0           10.0     30000.0
# 3      Egypt       Ethiopia            4.0            0.0     30000.0
# 4     Sudan        Ethiopia            1.0            0.0     20000.0

# %%
#9.program to sort the dataframe by "HomeTeam" in ascending order then 'HomeTeamGoals' in descending order
sorted_df=df.sort_values(by=['HomeTeam','Home TeamGoals'], ascending=[True, False])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12044\939576031.py in ?()
#       1 #9.program to sort the dataframe by "HomeTeam" in ascending order then 'HomeTeamGoals' in descending order
# ----> 2 sorted_df=df.sort_values(by=['HomeTeam','Home TeamGoals'], ascending=[True, False])
#       3 df.head()
#
# c:\Users\DELL\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7168                 f"Length of ascending ({len(ascending)})"  # type: ignore[arg-type]
#    7169                 f" != length of by ({len(by)})"
#    7170             )
#    7171         if len(by) > 1:
# -> 7172             keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    7173
#    7174             # need to rewrap columns in Series to apply key function
# ...

# %%
#10.program to get list from dataframe column headers
column_headers = df.columns.tolist()
print(column_headers)
# Out:
# ['HomeTeam', 'AwayTeam', 'HomeTeamGoals', 'AwayTeamGoals', 'Attendance']

# %%
#11.append a column 'New'
df['New'] = 'New Column'
print(df.head())
# Out:
#     HomeTeam       AwayTeam  HomeTeamGoals  AwayTeamGoals  Attendance  \
# 0     Sudan           Egypt            1.0            2.0     30000.0
# 1  Ethiopia    South Africa            NaN            NaN         NaN
# 2     Egypt        Ethiopia            4.0           10.0     30000.0
# 3      Egypt       Ethiopia            4.0            0.0     30000.0
# 4     Sudan        Ethiopia            1.0            0.0     20000.0
#
#           New
# 0  New Column
# 1  New Column
# 2  New Column
# 3  New Column
# 4  New Column

# %%
#12.add 2 rows to dataframe
new_rows = pd.DataFrame({
    'HomeTeam': ['Team A', 'Team B'],
    'AwayTeam': ['Team C', 'Team D'],
    'HomeTeamGoals': [1, 2],
    'AwayTeamGoals': [0, 1],
    'Attendance': [1000, 2000],
    'New': ['New Row A', 'New Row B']
})

# %%
#13.change country 'Uganda' to 'China' in the 'AwayTeam' column of  the dataframe
df['AwayTeam'] = df['AwayTeam'].replace('Uganda', 'China')

# %%
#14.program to reset index in dataframe
df.reset_index(drop=True, inplace=True)

# %%
#15.program to check whether the stadium column is present in the dataframe
if 'Stadium' in df.columns:
    print("Stadium column is present.")
else:
    print("Stadium column is not present.")
# Out:
# Stadium column is not present.

# %%
#16.convert the datatype of 'AwayTeamGoals' column int to float
df['AwayTeamGoals'] = df['AwayTeamGoals'].astype(float)

# %%
#17.remove last 10 rows from the dataframe
df = df[:-10]

# %%
df.shape
# Out:
# (612, 6)

# %%
#18.iterate over rows in the dataframe
for index, row in df.iterrows():
    print(f"Row {index}: Home Team: {row['HomeTeam']}, Away Team: {row['AwayTeam']}, Home Goals: {row['HomeTeamGoals']}, Away Goals: {row['AwayTeamGoals']}")
# Out:
# Row 0: Home Team: Sudan , Away Team:  Egypt, Home Goals: 1.0, Away Goals: 2.0
# Row 1: Home Team: Ethiopia , Away Team:  South Africa, Home Goals: nan, Away Goals: nan
# Row 2: Home Team: Egypt , Away Team:  Ethiopia, Home Goals: 4.0, Away Goals: 10.0
# Row 3: Home Team: Egypt, Away Team:  Ethiopia, Home Goals: 4.0, Away Goals: 0.0
# Row 4: Home Team: Sudan , Away Team:  Ethiopia, Home Goals: 1.0, Away Goals: 0.0
# Row 5: Home Team: Egypt, Away Team:  Sudan, Home Goals: 2.0, Away Goals: 1.0
# Row 6: Home Team: Ethiopia , Away Team:  Tunisia, Home Goals: 4.0, Away Goals: 2.0
# Row 7: Home Team: Egypt, Away Team:  Uganda, Home Goals: 2.0, Away Goals: 1.0
# Row 8: Home Team: Tunisia , Away Team:  Uganda, Home Goals: 3.0, Away Goals: 0.0
# Row 9: Home Team: Ethiopia , Away Team: Egypt, Home Goals: 4.0, Away Goals: 2.0
# Row 10: Home Team: Ghana , Away Team:  Tunisia, Home Goals: 1.0, Away Goals: 1.0
# Row 11: Home Team: Ghana , Away Team:  Ethiopia, Home Goals: 2.0, Away Goals: 0.0
# ...

# %%
#19.change orderof columns in the dataframe
df = df[['HomeTeam', 'AwayTeam', 'HomeTeamGoals', 'AwayTeamGoals', 'Attendance', 'New']]
